# %%
import sys
print(sys.executable)
# Out:
# /Users/mikayla/wallet-wisdom/env-xgboost/bin/python

# %%
# dependecies
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score
import random
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns
import xgboost as xgb
from xgboost import XGBClassifier

# %%
# for all my plots
palette = ['#C66F80', '#F4C7D0','#FCEBF1', '#4A6644', '#9FAA74', '#D7DAB3', '#ECE3D2']
customCmap = ListedColormap(palette)

# %%
data = pd.read_csv('personalFinanceDataset.csv')
data.head()
# Out:
#    Unnamed: 0  age  gender           raceEthnicity                 education  \
# 0           0   35  Female                   White               High School
# 1           1   65  Female  Black/African American               High School
# 2           2   50    Male       Other/Multiracial                Bachelor's
# 3           3   40  Female                   White                Bachelor's
# 4           4   30    Male  Black/African American  Some College/Associate's
#
#     region householdType  householdSize      career workArrangement  ...  \
# 0    South         DINKS              2      Retail          Office  ...
# 1    South        Single              1     Retired         Retired  ...
# 2  Midwest  SingleParent              3  Healthcare          Office  ...
# 3     West        Single              1       Sales          Office  ...
# 4  Midwest   SmallFamily              4     Service          Office  ...
#
#    totalExpenses  totalSavingsInvestments  monthlyCashFlow housingRatio  \
# 0        5368.49                   143.09         -2949.78        66.32
# 1        5258.28                     0.00          -169.98        25.51
# 2        6578.61                     0.00         -1780.63        37.63
# 3        7676.07                   954.95          -598.56        28.46
# 4        7640.68                   254.91         -5375.15        57.12
#
#    debtToIncome  savingsInvestmentsRate  carPaymentRatio  monthsSaved  \
# 0          1.33                    5.59             0.00         1.17
# 1         25.51                    0.00            13.95         0.07
# 2         11.88                    0.00             8.04         0.93
# 3         14.87                   11.89            11.36         1.17
# 4         27.03                   10.11            15.16         1.37
#
#          financialHealth  ageCategory
# 0  FinanciallyDistressed        30-35
# 1  FinanciallyDistressed        60-65
# 2  FinanciallyDistressed        45-50
# 3      FinanciallyStable        35-40
# 4  FinanciallyDistressed        25-30
#
# [5 rows x 70 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 70 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  3500 non-null   int64
#  1   age                         3500 non-null   int64
#  2   gender                      3500 non-null   object
#  3   raceEthnicity               3500 non-null   object
#  4   education                   3500 non-null   object
#  5   region                      3500 non-null   object
#  6   householdType               3500 non-null   object
#  7   householdSize               3500 non-null   int64
#  8   career                      3500 non-null   object
#  9   workArrangement             3500 non-null   object
#  10  annualIncome                3500 non-null   float64
#  11  sideHustleIncome            3500 non-null   float64
#  12  monthlyIncome               3500 non-null   float64
#  13  housingStatus               3500 non-null   object
#  14  housingCost                 3500 non-null   float64
#  15  propertyTax                 3500 non-null   float64
#  16  hoaFees                     3500 non-null   float64
#  17  homeInsurance               3500 non-null   float64
#  18  utilities                   3500 non-null   float64
#  19  internet                    3500 non-null   float64
#  20  phone                       3500 non-null   float64
#  21  ownsCar                     3500 non-null   bool
#  22  carPayment                  3500 non-null   float64
#  23  carInsurance                3500 non-null   float64
#  24  gas                         3500 non-null   float64
#  25  publicTransit               3500 non-null   float64
#  26  carMaintenance              3500 non-null   float64
#  27  healthInsurance             3500 non-null   float64
#  28  oopMedical                  3500 non-null   float64
#  29  dentalVision                3500 non-null   float64
#  30  lifeInsurance               3500 non-null   float64
#  31  studentLoans                3500 non-null   float64
#  32  ccPayment                   3500 non-null   float64
#  33  personalLoans               3500 non-null   float64
#  34  medicalDebt                 3500 non-null   float64
#  35  groceries                   3500 non-null   float64
#  36  diningOut                   3500 non-null   float64
#  37  coffee                      3500 non-null   float64
#  38  alcohol                     3500 non-null   float64
#  39  streaming                   3500 non-null   float64
#  40  musicStreaming              3500 non-null   float64
#  41  gaming                      3500 non-null   float64
#  42  gym                         3500 non-null   float64
#  43  otherSubscriptions          3500 non-null   float64
#  44  clothing                    3500 non-null   float64
#  45  personalCare                3500 non-null   float64
#  46  householdSupplies           3500 non-null   float64
#  47  childcare                   3500 non-null   float64
#  48  petExpenses                 3500 non-null   float64
#  49  entertainment               3500 non-null   float64
#  50  hobbies                     3500 non-null   float64
#  51  travel                      3500 non-null   float64
#  52  gifts                       3500 non-null   float64
#  53  donations                   3500 non-null   float64
#  54  retirement401k              3500 non-null   float64
#  55  iraContribution             3500 non-null   float64
#  56  emergencyFundContributions  3500 non-null   float64
#  57  generalSavings              3500 non-null   float64
#  58  investmentContributions     3500 non-null   float64
#  59  contributions529            3500 non-null   float64
#  60  totalExpenses               3500 non-null   float64
#  61  totalSavingsInvestments     3500 non-null   float64
#  62  monthlyCashFlow             3500 non-null   float64
#  63  housingRatio                3500 non-null   float64
#  64  debtToIncome                3500 non-null   float64
#  65  savingsInvestmentsRate      3500 non-null   float64
#  66  carPaymentRatio             3500 non-null   float64
#  67  monthsSaved                 3500 non-null   float64
#  68  financialHealth             3500 non-null   object
#  69  ageCategory                 3500 non-null   object
# dtypes: bool(1), float64(56), int64(3), object(10)
# memory usage: 1.8+ MB

# %%
data = data.drop(['Unnamed: 0'], axis=1)

# %%
data.head()
# Out:
#    age  gender           raceEthnicity                 education   region  \
# 0   35  Female                   White               High School    South
# 1   65  Female  Black/African American               High School    South
# 2   50    Male       Other/Multiracial                Bachelor's  Midwest
# 3   40  Female                   White                Bachelor's     West
# 4   30    Male  Black/African American  Some College/Associate's  Midwest
#
#   householdType  householdSize      career workArrangement  annualIncome  ...  \
# 0         DINKS              2      Retail          Office  30741.640000  ...
# 1        Single              1     Retired         Retired  61059.581194  ...
# 2  SingleParent              3  Healthcare          Office  57575.730000  ...
# 3        Single              1       Sales          Office  96389.510000  ...
# 4   SmallFamily              4     Service          Office  30245.270000  ...
#
#    totalExpenses  totalSavingsInvestments monthlyCashFlow  housingRatio  \
# 0        5368.49                   143.09        -2949.78         66.32
# 1        5258.28                     0.00         -169.98         25.51
# 2        6578.61                     0.00        -1780.63         37.63
# 3        7676.07                   954.95         -598.56         28.46
# 4        7640.68                   254.91        -5375.15         57.12
#
#    debtToIncome  savingsInvestmentsRate  carPaymentRatio  monthsSaved  \
# 0          1.33                    5.59             0.00         1.17
# 1         25.51                    0.00            13.95         0.07
# 2         11.88                    0.00             8.04         0.93
# 3         14.87                   11.89            11.36         1.17
# 4         27.03                   10.11            15.16         1.37
#
#          financialHealth  ageCategory
# 0  FinanciallyDistressed        30-35
# 1  FinanciallyDistressed        60-65
# 2  FinanciallyDistressed        45-50
# 3      FinanciallyStable        35-40
# 4  FinanciallyDistressed        25-30
#
# [5 rows x 69 columns]

# %%
data.isnull().sum()
# Out:
# age                       0
# gender                    0
# raceEthnicity             0
# education                 0
# region                    0
#                          ..
# savingsInvestmentsRate    0
# carPaymentRatio           0
# monthsSaved               0
# financialHealth           0
# ageCategory               0
# Length: 69, dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (3500, 69)

# %%
# making all categorical values numerical => correlation table (one hot encoding)
ohe_gender = pd.get_dummies(data.gender)
ohe_raceEthnicity = pd.get_dummies(data.raceEthnicity)
ohe_education = pd.get_dummies(data.education)
ohe_region = pd.get_dummies(data.region)
ohe_householdType = pd.get_dummies(data.householdType)
ohe_career = pd.get_dummies(data.career)
ohe_workArrangement = pd.get_dummies(data.workArrangement)
ohe_housingStatus = pd.get_dummies(data.housingStatus)

# %%
# the previous one hot encoding messes with the one with the synthetic data
# will probably rework the entire notebook to align and be easier to go back and read
dataOHE = pd.concat([data, ohe_gender, ohe_career, ohe_education, ohe_householdType, ohe_housingStatus, ohe_raceEthnicity, ohe_region, ohe_workArrangement], axis='columns')
data.head()
# Out:
#    age  gender           raceEthnicity                 education   region  \
# 0   35  Female                   White               High School    South
# 1   65  Female  Black/African American               High School    South
# 2   50    Male       Other/Multiracial                Bachelor's  Midwest
# 3   40  Female                   White                Bachelor's     West
# 4   30    Male  Black/African American  Some College/Associate's  Midwest
#
#   householdType  householdSize      career workArrangement  annualIncome  ...  \
# 0         DINKS              2      Retail          Office  30741.640000  ...
# 1        Single              1     Retired         Retired  61059.581194  ...
# 2  SingleParent              3  Healthcare          Office  57575.730000  ...
# 3        Single              1       Sales          Office  96389.510000  ...
# 4   SmallFamily              4     Service          Office  30245.270000  ...
#
#    totalExpenses  totalSavingsInvestments monthlyCashFlow  housingRatio  \
# 0        5368.49                   143.09        -2949.78         66.32
# 1        5258.28                     0.00         -169.98         25.51
# 2        6578.61                     0.00        -1780.63         37.63
# 3        7676.07                   954.95         -598.56         28.46
# 4        7640.68                   254.91        -5375.15         57.12
#
#    debtToIncome  savingsInvestmentsRate  carPaymentRatio  monthsSaved  \
# 0          1.33                    5.59             0.00         1.17
# 1         25.51                    0.00            13.95         0.07
# 2         11.88                    0.00             8.04         0.93
# 3         14.87                   11.89            11.36         1.17
# 4         27.03                   10.11            15.16         1.37
#
#          financialHealth  ageCategory
# 0  FinanciallyDistressed        30-35
# 1  FinanciallyDistressed        60-65
# 2  FinanciallyDistressed        45-50
# 3      FinanciallyStable        35-40
# 4  FinanciallyDistressed        25-30
#
# [5 rows x 69 columns]

# %% [markdown]
# writing down some things i want to explore
#  1. want to see correlations in different categories
#  - more specific one : debt & discretionary
#  2. want to see feature importance (which feature has the biggest impact on financial status)
#  3. think wanted to learn xg boost model - def want to build a model anyway to simulate real people
#  - wanna experiment on lesser features used to train; bc not everyone would have all these numbers ready to go
#  4. are there any instances that break the original proportions

# %%
df = data[['studentLoans', 'entertainment', 'hobbies', 'travel', 'gifts', 'donations', 'ccPayment', 'personalLoans', 'medicalDebt']].copy()
df.head()
# Out:
#    studentLoans  entertainment  hobbies  travel   gifts  donations  ccPayment  \
# 0           0.0         100.49     0.00   29.91  104.82        0.0      33.95
# 1           0.0          69.68    15.04   52.88   51.07        0.0     588.29
# 2           0.0          43.27    89.37   84.82  105.51        0.0      11.58
# 3         231.8         147.07     0.00  248.83  129.29        0.0      49.99
# 4           0.0          67.81    45.34   25.03   32.54        0.0     299.09
#
#    personalLoans  medicalDebt
# 0           0.00          0.0
# 1           0.00          0.0
# 2         172.32          0.0
# 3           0.00          0.0
# 4           0.00          0.0

# %%
correlationMatrix = df.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlationMatrix, annot=True, cmap=customCmap, 
            fmt='.1f', square=True, linewidths=0.5)
plt.title('Correlation Matrix between Debt & Discretionary Spending',)
plt.tight_layout()
plt.show()

# %%
# creating some cross tables
crosstab01 = pd.crosstab(data['career'], data['financialHealth'])
crosstab02 = pd.crosstab(data['financialHealth'], data['householdType'])
crosstab03 = pd.crosstab(data['ageCategory'], data['career'])
crosstab04 = pd.crosstab(data['financialHealth'], data['career'])
crosstab04
# Out:
# career                 Admin  Business  Construction  Education  Engineering  \
# financialHealth
# FinanciallyDistressed    183        46            88         51           16
# FinanciallyStable         12        58             4         35           57
# FinanciallyThriving        0        11             0          7           19
# FinanciallyVulnerable    116        86            59        100           68
#
# career                 Finance  FoodService  Healthcare  Legal  Manufacturing  \
# financialHealth
# FinanciallyDistressed       12          197         170      1            188
# FinanciallyStable           50            0          46     11             11
# FinanciallyThriving         18            0           9      4              0
# FinanciallyVulnerable       73           34         192      8            126
#
# career                 PartTime  Research  Retail  Retired  Sales  Service  \
# financialHealth
# FinanciallyDistressed        36         0     355       81     83       61
# FinanciallyStable             0         1       0        7     30        0
# FinanciallyThriving           0         3       0        2      3        0
# FinanciallyVulnerable        10         8      83       48    108       24
#
# career                 Technology  Transportation
# financialHealth
# FinanciallyDistressed          24             112
# FinanciallyStable              78               3
# FinanciallyThriving            35               0
# FinanciallyVulnerable          87              52

# %%
crosstab02.plot(kind='bar', stacked=True, colormap=customCmap, figsize=(12, 6))
# Out:
# <Axes: xlabel='financialHealth'>

# %%
sns.countplot(data=data, x='financialHealth')
plt.title('Distribution of Financial Health')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# MODELING
# 1. xg boost 2. knn 3. gan

# %%
# about to begin process of using xgboost vastly for feature importance data
# must first label encode y variable
le = LabelEncoder()
y = le.fit_transform(data['financialHealth']) # works for the target variable, not for features

# %%
data.select_dtypes(include='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   gender           3500 non-null   object
#  1   raceEthnicity    3500 non-null   object
#  2   education        3500 non-null   object
#  3   region           3500 non-null   object
#  4   householdType    3500 non-null   object
#  5   career           3500 non-null   object
#  6   workArrangement  3500 non-null   object
#  7   housingStatus    3500 non-null   object
#  8   financialHealth  3500 non-null   object
#  9   ageCategory      3500 non-null   object
# dtypes: object(10)
# memory usage: 273.6+ KB

# %%
# test train split
x = data.drop(['gender','raceEthnicity', 'education', 'region', 'householdType',
              'career', 'workArrangement', 'housingStatus', 'financialHealth',
              'ageCategory'], axis=1)
featureNames = x.columns
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
yTrain = yTrain.flatten()
yTrain.shape
# Out:
# (2800,)

# %%
xTrain = xTrain.astype('float32').values
xTest = xTest.astype('float32').values
yTrain = yTrain.astype('int')

# %%
print('Original dataset: %d training samples & %d testing samples\n' % (
    len(xTrain), len(xTest)
))
# Out:
# Original dataset: 2800 training samples & 700 testing samples

# %%
# model
model = XGBClassifier(random_state=42, n_estimators=100, max_depth=4)
model.fit(xTrain, yTrain)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
# evaluate
yPred = model.predict(xTest)
print(classification_report(yTest, yPred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       321
#            1       0.86      0.86      0.86        87
#            2       0.88      0.65      0.75        23
#            3       0.94      0.97      0.95       269
#
#     accuracy                           0.95       700
#    macro avg       0.92      0.87      0.89       700
# weighted avg       0.95      0.95      0.95       700

# %%
print(le.classes_)
# Out:
# ['FinanciallyDistressed' 'FinanciallyStable' 'FinanciallyThriving'
#  'FinanciallyVulnerable']

# %%
# confusion matrix
cm = confusion_matrix(yTest, yPred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap=customCmap, xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix', fontsize = 16, fontweight = 'bold')
plt.xlabel('Predicted Label', fontsize = 12)
plt.ylabel('True Label', fontsize = 12)
plt.tight_layout()

# %%
# confusion matrix w/ percentages
cm = confusion_matrix(yTest, yPred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm / np.sum(cm), annot=True, fmt='.2%', cmap=customCmap, xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix', fontsize = 16, fontweight = 'bold')
plt.xlabel('Predicted Label', fontsize = 12)
plt.ylabel('True Label', fontsize = 12)
plt.tight_layout()

# %%
# feature importance
xgb.plot_importance(model, max_num_features=10)
plt.show()

# %%
# Get feature importances as a dictionary
importances = model.get_booster().get_score(importance_type='weight')

# Match them to the real column names
feature_map = {f"f{i}": col for i, col in enumerate(featureNames)}

# Translate importances
named_importances = {feature_map.get(k, k): v for k, v in importances.items()}

# Sort and view
import pandas as pd
pd.Series(named_importances).sort_values(ascending=False)
# Out:
# monthsSaved                   538.0
# housingRatio                  438.0
# savingsInvestmentsRate        401.0
# monthlyCashFlow               344.0
# debtToIncome                  311.0
# totalSavingsInvestments       161.0
# carPaymentRatio               127.0
# streaming                      70.0
# coffee                         67.0
# clothing                       64.0
# hobbies                        61.0
# alcohol                        61.0
# oopMedical                     57.0
# homeInsurance                  56.0
# gas                            51.0
# householdSupplies              51.0
# entertainment                  49.0
# healthInsurance                46.0
# totalExpenses                  45.0
# travel                         45.0
# carMaintenance                 44.0
# ccPayment                      44.0
# phone                          42.0
# gifts                          40.0
# retirement401k                 38.0
# utilities                      36.0
# diningOut                      34.0
# petExpenses                    33.0
# dentalVision                   31.0
# emergencyFundContributions     31.0
# internet                       30.0
# personalCare                   30.0
# otherSubscriptions             29.0
# groceries                      28.0
# carPayment                     28.0
# carInsurance                   28.0
# housingCost                    26.0
# studentLoans                   25.0
# age                            21.0
# investmentContributions        21.0
# monthlyIncome                  20.0
# medicalDebt                    19.0
# generalSavings                 18.0
# musicStreaming                 18.0
# annualIncome                   17.0
# gaming                         17.0
# gym                            15.0
# iraContribution                13.0
# propertyTax                    13.0
# childcare                      13.0
# personalLoans                  11.0
# lifeInsurance                  10.0
# donations                      10.0
# sideHustleIncome               10.0
# hoaFees                         7.0
# contributions529                2.0
# publicTransit                   2.0
# dtype: float64

# %% [markdown]
# i want to do a KNN model & test out the differences in my synthetic data made using a python script vs using a GAN and seeing the similarities & differences in the XG Boost & KNN models

# %%
# test train split
x = data[['monthsSaved', 'housingRatio', 'savingsInvestmentsRate', 'monthlyCashFlow',
          'debtToIncome', 'totalSavingsInvestments', 'carPaymentRatio', 'homeInsurance',
          'streaming', 'clothing', 'healthInsurance', 'alcohol', 'oopMedical',
          'coffee', 'ccPayment', 'hobbies', 'travel', 'householdSupplies']].copy() # had to reduce the # of features bc of knn dimensionality issues
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
xTrain = scaler.fit_transform(xTrain)
xTest = scaler.transform(xTest)

# %%
kRange = range(5, 10)
cvScores = []

for k in kRange:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, xTrain, yTrain, cv=5, scoring='f1_macro')
    cvScores.append(scores.mean())

# %%
plt.plot(kRange, cvScores, marker='o')
plt.xlabel('k')
plt.ylabel('Cross-Validated Accuracy')
plt.title('Optimal k for KNN')
plt.grid(True)
plt.show()

best_k = kRange[cvScores.index(max(cvScores))]
print(f"Best k: {best_k}")
# Out:
# Best k: 8

# %%
knn = KNeighborsClassifier(n_neighbors=9)
knn.fit(xTrain, yTrain)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
yPred = knn.predict(xTest)

# %%
# evaluate
print(classification_report(yTest, yPred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       321
#            1       0.61      0.39      0.48        87
#            2       0.80      0.35      0.48        23
#            3       0.69      0.72      0.71       269
#
#     accuracy                           0.74       700
#    macro avg       0.73      0.59      0.63       700
# weighted avg       0.74      0.74      0.73       700

# %%
# confusion matrix
cm = confusion_matrix(yTest, yPred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap=customCmap, xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix', fontsize = 16, fontweight = 'bold')
plt.xlabel('Predicted Label', fontsize = 12)
plt.ylabel('True Label', fontsize = 12)
plt.tight_layout()

# %% [markdown]
# train on real, test on GAN
# train on gan, test on real

# %%
data.describe()
# Out:
#                age  householdSize   annualIncome  sideHustleIncome  \
# count  3500.000000    3500.000000    3500.000000       3500.000000
# mean     40.064286       2.455429   59539.278108       1546.698483
# std      12.041660       1.220250   33832.018375       3892.535837
# min      25.000000       1.000000   12155.920000          0.000000
# 25%      30.000000       1.000000   34884.992500          0.000000
# 50%      40.000000       2.000000   47231.810000          0.000000
# 75%      50.000000       3.000000   76935.252500          0.000000
# max      70.000000       5.000000  201295.130000      32971.110000
#
#        monthlyIncome  housingCost  propertyTax      hoaFees  homeInsurance  \
# count    3500.000000  3500.000000  3500.000000  3500.000000    3500.000000
# mean     5090.498049  2270.902540   102.326491    33.250726      81.362666
# std      2918.055046  1021.381043   122.870009    88.553225      62.717842
# min      1012.993333   718.150000     0.000000     0.000000      15.000000
# 25%      2969.896250  1551.505000     0.000000     0.000000      24.295000
# 50%      4057.659583  2034.240000     0.000000     0.000000      34.635000
# 75%      6550.168750  2727.412500   185.682500     0.000000     139.357500
# max     18897.110000  9244.410000   770.370000   399.440000     199.990000
#
#          utilities  ...  investmentContributions  contributions529  \
# count  3500.000000  ...              3500.000000       3500.000000
# mean    205.842951  ...                78.924460         16.939126
# std      43.061886  ...               218.948555         74.893699
# min     123.320000  ...                 0.000000          0.000000
# 25%     173.782500  ...                 0.000000          0.000000
# 50%     200.105000  ...                 0.000000          0.000000
# 75%     232.470000  ...                 0.000000          0.000000
# max     376.950000  ...              1198.380000        499.380000
#
#        totalExpenses  totalSavingsInvestments  monthlyCashFlow  housingRatio  \
# count    3500.000000              3500.000000      3500.000000   3500.000000
# mean     7151.009237               445.867654     -2506.378837     52.178180
# std      2536.134796               551.315408      2146.910010     23.751874
# min      2667.440000                 0.000000    -10432.580000     11.660000
# 25%      5271.335000                60.137500     -3862.927500     34.727500
# 50%      6691.155000               257.490000     -2368.075000     47.925000
# 75%      8447.297500               598.690000     -1262.027500     65.490000
# max     20228.600000              3914.050000      5783.490000    211.920000
#
#        debtToIncome  savingsInvestmentsRate  carPaymentRatio  monthsSaved
# count   3500.000000             3500.000000      3500.000000  3500.000000
# mean      12.861523                7.418869         5.325757     1.813746
# std       10.096991                6.430781         7.766051     1.386904
# min        0.000000                0.000000         0.000000     0.000000
# 25%        4.827500                2.030000         0.000000     0.840000
# 50%       10.825000                6.605000         0.000000     1.490000
# 75%       19.652500               11.302500        12.552500     2.350000
# max       53.480000               33.840000        27.700000     6.000000
#
# [8 rows x 58 columns]

# %%
synData = pd.read_csv('synData.csv')

# %%
synData.head()
# Out:
#    age  gender           raceEthnicity                 education   region  \
# 0   31    Male                   White                Bachelor's    South
# 1   50  Female                   Asian               High School  Midwest
# 2   42    Male                   White  Some College/Associate's    South
# 3   25    Male                   White  Some College/Associate's  Midwest
# 4   61  Female  Black/African American                Bachelor's    South
#
#   householdType  householdSize         career workArrangement  annualIncome  \
# 0         Other              2         Retail          Office  20735.784791
# 1         DINKS              3     Healthcare          Office  88419.040967
# 2     Roommates              2         Retail          Hybrid  29440.539611
# 3  SingleParent              1  Manufacturing          Hybrid  51488.705675
# 4         Other              4       Business          Office  33798.920912
#
#    ...  totalExpenses  totalSavingsInvestments monthlyCashFlow  housingRatio  \
# 0  ...    5259.036875              1508.348715      279.594411     40.005986
# 1  ...    4681.839130              2282.909017       92.799302     21.504035
# 2  ...    7318.791074                55.342397    -1785.654438    109.752385
# 3  ...    7646.014288               290.585052     -448.049187     15.944974
# 4  ...    6783.682666              2561.448598     -790.128703     14.964838
#
#    debtToIncome  savingsInvestmentsRate  carPaymentRatio  monthsSaved  \
# 0     20.203418               13.300729        -0.272846     2.038898
# 1     36.983144                7.923803         0.224076     2.528271
# 2      3.077163                8.880924         0.580108     1.524849
# 3     11.747448               14.177564         0.507766     3.610195
# 4      3.109067               14.420531         0.482580     2.131422
#
#          financialHealth  ageCategory
# 0  FinanciallyVulnerable        25-30
# 1  FinanciallyDistressed        35-40
# 2  FinanciallyVulnerable        30-35
# 3    FinanciallyThriving        40-45
# 4  FinanciallyVulnerable        60-65
#
# [5 rows x 69 columns]

# %%
synData.describe()
# Out:
#                age  householdSize   annualIncome  sideHustleIncome  \
# count  3500.000000    3500.000000    3500.000000       3500.000000
# mean     45.315429       2.232000   35983.476798        545.523905
# std      14.060070       1.062443   23980.971833       2713.508204
# min      23.000000       1.000000  -12310.922637       -607.290157
# 25%      31.000000       2.000000   18836.613360        -26.596676
# 50%      45.000000       2.000000   29436.582404         60.178044
# 75%      55.000000       3.000000   46472.142626        141.630136
# max      79.000000       6.000000  178679.297736      36790.846920
#
#        monthlyIncome  housingCost  propertyTax      hoaFees  homeInsurance  \
# count    3500.000000  3500.000000  3500.000000  3500.000000    3500.000000
# mean     5396.302800  2677.828427    58.464640     8.361807      78.256084
# std      3507.714084  1197.673714    88.293120    46.681343      60.411478
# min      -241.375979   451.075151   -81.651329    -6.188429       3.451740
# 25%      2870.139468  1835.367629    -6.288354    -1.360691      23.985229
# 50%      4285.136770  2440.614842     2.443285     0.638513      69.435092
# 75%      6940.902674  3255.022238   111.642884     2.605855     129.396694
# max     19778.133397  8702.621247   751.263613   489.093285     224.186024
#
#          utilities  ...  investmentContributions  contributions529  \
# count  3500.000000  ...              3500.000000       3500.000000
# mean    200.168421  ...                43.213783          0.564752
# std      50.567919  ...               188.660356         25.191283
# min     100.749994  ...               -11.583923        -32.727609
# 25%     163.488373  ...                 4.036233         -3.061134
# 50%     193.530942  ...                 7.924727         -1.874187
# 75%     229.029815  ...                11.321737         -0.457470
# max     402.368917  ...              1635.167752        532.781604
#
#        totalExpenses  totalSavingsInvestments  monthlyCashFlow  housingRatio  \
# count    3500.000000              3500.000000      3500.000000   3500.000000
# mean     5669.218905               916.131762     -1321.064062     52.924450
# std      2311.053458               915.268566      2425.096698     24.185791
# min       382.335773               -67.797957     -9902.160256      6.899938
# 25%      4070.914584               137.922244     -2707.711463     34.950868
# 50%      5283.120287               614.371099     -1329.698656     50.114933
# 75%      6748.556528              1384.840545      -158.693225     66.903318
# max     18530.753239              5175.446679      8328.780138    189.694183
#
#        debtToIncome  savingsInvestmentsRate  carPaymentRatio  monthsSaved
# count   3500.000000             3500.000000      3500.000000  3500.000000
# mean      15.396461               11.363017         6.147293     2.755900
# std       13.668691                8.455661         9.955177     1.570419
# min       -2.318697               -1.729045        -0.546799    -0.347599
# 25%        3.013015                5.182654         0.259533     1.691323
# 50%       11.897547               10.432163         0.473030     2.290883
# 75%       24.474650               16.348196        13.719854     3.952288
# max       58.966598               40.495907        32.947272     7.369317
#
# [8 rows x 58 columns]

# %%
syndf = synData[['monthlyCashFlow', 'debtToIncome', 'housingCost', 'personalCare', 'phone',
                 'groceries']].copy()
syndf.head()
# Out:
#    monthlyCashFlow  debtToIncome  housingCost  personalCare       phone  \
# 0       279.594411     20.203418  1884.294399    128.744223  136.983541
# 1        92.799302     36.983144  2881.210611    150.667875   73.339385
# 2     -1785.654438      3.077163  2199.132271    145.475909   71.809593
# 3      -448.049187     11.747448  3016.999455     39.770271   85.565465
# 4      -790.128703      3.109067  3596.179013    118.091192   88.400456
#
#      groceries
# 0  1187.925751
# 1   645.479695
# 2  1326.525362
# 3   469.537978
# 4   974.782906

# %%
cm = syndf.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, cmap=customCmap, 
            fmt='.1f', square=True, linewidths=0.5)
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()

# %%
# quick distribution of synthetic data
sns.countplot(data=synData, x='financialHealth')
plt.title('Distribution of Financial Health')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# COMPARING DATASETS MODELING

# %%
catCols = data.select_dtypes(include=['object', 'boolean']).columns.tolist()

# %%
catCols
# Out:
# ['gender',
#  'raceEthnicity',
#  'education',
#  'region',
#  'householdType',
#  'career',
#  'workArrangement',
#  'housingStatus',
#  'ownsCar',
#  'financialHealth',
#  'ageCategory']

# %%
# Diagnostic code - run this first to identify the problem
print("Original data columns:", data.columns.tolist())
print("Synthetic data columns:", synData.columns.tolist())
print("\nDuplicate columns in original data:", data.columns[data.columns.duplicated()].tolist())
print("Duplicate columns in synthetic data:", synData.columns[synData.columns.duplicated()].tolist())
# Out:
# Original data columns: ['age', 'gender', 'raceEthnicity', 'education', 'region', 'householdType', 'householdSize', 'career', 'workArrangement', 'annualIncome', 'sideHustleIncome', 'monthlyIncome', 'housingStatus', 'housingCost', 'propertyTax', 'hoaFees', 'homeInsurance', 'utilities', 'internet', 'phone', 'ownsCar', 'carPayment', 'carInsurance', 'gas', 'publicTransit', 'carMaintenance', 'healthInsurance', 'oopMedical', 'dentalVision', 'lifeInsurance', 'studentLoans', 'ccPayment', 'personalLoans', 'medicalDebt', 'groceries', 'diningOut', 'coffee', 'alcohol', 'streaming', 'musicStreaming', 'gaming', 'gym', 'otherSubscriptions', 'clothing', 'personalCare', 'householdSupplies', 'childcare', 'petExpenses', 'entertainment', 'hobbies', 'travel', 'gifts', 'donations', 'retirement401k', 'iraContribution', 'emergencyFundContributions', 'generalSavings', 'investmentContributions', 'contributions529', 'totalExpenses', 'totalSavingsInvestments', 'monthlyCashFlow', 'housingRatio', 'debtToIncome', 'savingsInvestmentsRate', 'carPaymentRatio', 'monthsSaved', 'financialHealth', 'ageCategory']
# Synthetic data columns: ['age', 'gender', 'raceEthnicity', 'education', 'region', 'householdType', 'householdSize', 'career', 'workArrangement', 'annualIncome', 'sideHustleIncome', 'monthlyIncome', 'housingStatus', 'housingCost', 'propertyTax', 'hoaFees', 'homeInsurance', 'utilities', 'internet', 'phone', 'ownsCar', 'carPayment', 'carInsurance', 'gas', 'publicTransit', 'carMaintenance', 'healthInsurance', 'oopMedical', 'dentalVision', 'lifeInsurance', 'studentLoans', 'ccPayment', 'personalLoans', 'medicalDebt', 'groceries', 'diningOut', 'coffee', 'alcohol', 'streaming', 'musicStreaming', 'gaming', 'gym', 'otherSubscriptions', 'clothing', 'personalCare', 'householdSupplies', 'childcare', 'petExpenses', 'entertainment', 'hobbies', 'travel', 'gifts', 'donations', 'retirement401k', 'iraContribution', 'emergencyFundContributions', 'generalSavings', 'investmentContributions', 'contributions529', 'totalExpenses', 'totalSavingsInvestments', 'monthlyCashFlow', 'housingRatio', 'debtToIncome', 'savingsInvestmentsRate', 'carPaymentRatio', 'monthsSaved', 'financialHealth', 'ageCategory']
#
# Duplicate columns in original data: []
# Duplicate columns in synthetic data: []

# %%
# removes duplicate columns
dataClean = data.reset_index(drop=True).copy()
synDataclean = synData.reset_index(drop=True).copy()

dataClean = dataClean.loc[:, ~dataClean.columns.duplicated()]
synDataclean = synDataclean.loc[:, ~synDataclean.columns.duplicated()]

# verify both have the same columns
print('Data columns:', dataClean.columns.tolist())
print('Synthetic Data columns:', synDataclean.columns.tolist())

# if columns don't match, align them
commonCols = dataClean.columns.intersection(synDataclean.columns)
dataClean = dataClean[commonCols]
synDataclean = synDataclean[commonCols]

# concatenate for OHE
full = pd.concat([dataClean, synDataclean], ignore_index=True)

# OHE
dummies = pd.get_dummies(full, columns=catCols, prefix=catCols)

# split back into data & synData
data = dummies.iloc[:len(dataClean)].copy()
synData = dummies.iloc[len(dataClean):].copy()
# Out:
# Data columns: ['age', 'gender', 'raceEthnicity', 'education', 'region', 'householdType', 'householdSize', 'career', 'workArrangement', 'annualIncome', 'sideHustleIncome', 'monthlyIncome', 'housingStatus', 'housingCost', 'propertyTax', 'hoaFees', 'homeInsurance', 'utilities', 'internet', 'phone', 'ownsCar', 'carPayment', 'carInsurance', 'gas', 'publicTransit', 'carMaintenance', 'healthInsurance', 'oopMedical', 'dentalVision', 'lifeInsurance', 'studentLoans', 'ccPayment', 'personalLoans', 'medicalDebt', 'groceries', 'diningOut', 'coffee', 'alcohol', 'streaming', 'musicStreaming', 'gaming', 'gym', 'otherSubscriptions', 'clothing', 'personalCare', 'householdSupplies', 'childcare', 'petExpenses', 'entertainment', 'hobbies', 'travel', 'gifts', 'donations', 'retirement401k', 'iraContribution', 'emergencyFundContributions', 'generalSavings', 'investmentContributions', 'contributions529', 'totalExpenses', 'totalSavingsInvestments', 'monthlyCashFlow', 'housingRatio', 'debtToIncome', 'savingsInvestmentsRate', 'carPaymentRatio', 'monthsSaved', 'financialHealth', 'ageCategory']
# Synthetic Data columns: ['age', 'gender', 'raceEthnicity', 'education', 'region', 'householdType', 'householdSize', 'career', 'workArrangement', 'annualIncome', 'sideHustleIncome', 'monthlyIncome', 'housingStatus', 'housingCost', 'propertyTax', 'hoaFees', 'homeInsurance', 'utilities', 'internet', 'phone', 'ownsCar', 'carPayment', 'carInsurance', 'gas', 'publicTransit', 'carMaintenance', 'healthInsurance', 'oopMedical', 'dentalVision', 'lifeInsurance', 'studentLoans', 'ccPayment', 'personalLoans', 'medicalDebt', 'groceries', 'diningOut', 'coffee', 'alcohol', 'streaming', 'musicStreaming', 'gaming', 'gym', 'otherSubscriptions', 'clothing', 'personalCare', 'householdSupplies', 'childcare', 'petExpenses', 'entertainment', 'hobbies', 'travel', 'gifts', 'donations', 'retirement401k', 'iraContribution', 'emergencyFundContributions', 'generalSavings', 'investmentContributions', 'contributions529', 'totalExpenses', 'totalSavingsInvestments', 'monthlyCashFlow', 'housingRatio', 'debtToIncome', 'savingsInvestmentsRate', 'carPaymentRatio', 'monthsSaved', 'financialHealth', 'ageCategory']

# %%
synData.head()
# Out:
#       age  householdSize  annualIncome  sideHustleIncome  monthlyIncome  \
# 3500   31              2  20735.784791         24.901517   17513.184447
# 3501   50              3  88419.040967        133.117057    5066.455172
# 3502   42              2  29440.539611        158.710727    1565.696683
# 3503   25              1  51488.705675         78.981174    7663.643626
# 3504   61              4  33798.920912         30.496186    7722.091188
#
#       housingCost  propertyTax   hoaFees  homeInsurance   utilities  ...  \
# 3500  1884.294399    48.165521 -2.738129     106.801531  224.038810  ...
# 3501  2881.210611   -12.298887  2.932124      78.890994  137.045981  ...
# 3502  2199.132271   248.471768  2.580829      74.606898  223.991206  ...
# 3503  3016.999455   144.473507 -1.069077      14.365809  117.356001  ...
# 3504  3596.179013    -7.329611  0.643896     129.580573  229.334325  ...
#
#       financialHealth_FinanciallyVulnerable  ageCategory_25-30  \
# 3500                                   True               True
# 3501                                  False              False
# 3502                                   True              False
# 3503                                  False              False
# 3504                                   True              False
#
#       ageCategory_30-35  ageCategory_35-40  ageCategory_40-45  \
# 3500              False              False              False
# 3501              False               True              False
# 3502               True              False              False
# 3503              False              False               True
# 3504              False              False              False
#
#       ageCategory_45-50  ageCategory_50-55  ageCategory_55-60  \
# 3500              False              False              False
# 3501              False              False              False
# 3502              False              False              False
# 3503              False              False              False
# 3504              False              False              False
#
#       ageCategory_60-65  ageCategory_65-70
# 3500              False              False
# 3501              False              False
# 3502              False              False
# 3503              False              False
# 3504               True              False
#
# [5 rows x 120 columns]

# %% [markdown]
# need to add the one hot encoded features on the synthetic data

# %%
# data split
synX = synData.drop(['gender', 'raceEthnicity', 'education', 'region', 'householdType',
              'career', 'workArrangement', 'housingStatus', 'financialHealth',
              'ageCategory'], axis=1)
synXtrain, synXtest, synYtrain, synYtest = train_test_split(synX, synY, test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 2
#       1 # data split
# ----> 2 synX = synData.drop(['gender', 'raceEthnicity', 'education', 'region', 'householdType',
#       3               'career', 'workArrangement', 'housingStatus', 'financialHealth',
#       4               'ageCategory'], axis=1)
#       5 synXtrain, synXtest, synYtrain, synYtest = train_test_split(synX, synY, test_size=0.2, random_state=42)
#
# File ~/wallet-wisdom/env-xgboost/lib/python3.11/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)   5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)   5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~/wallet-wisdom/env-xgboost/lib/python3.11/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/wallet-wisdom/env-xgboost/lib/python3.11/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~/wallet-wisdom/env-xgboost/lib/python3.11/site-packages/pandas/core/indexes/base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['gender', 'raceEthnicity', 'education', 'region', 'householdType', 'career', 'workArrangement', 'housingStatus', 'financialHealth', 'ageCategory'] not found in axis"

# %%
# need to ensure shape is proper for xg boost model
synYtrain = synYtrain.flatten()
synYtrain.shape

# %%
synXtrain = synXtrain.astype('float32').values
synXtest = synXtest.astype('float32').values
synYtrain = synYtrain.astype('int')

# %%
# model (trained with syn data)
synModel = XGBClassifier(random_state=42, n_estimators=100, max_depth=4)
synModel.fit(synXtrain, synYtrain)

# %%
# evaluate (syn data on syn model)
synYpred = synModel.predict(synXtest)
print(classification_report(synYtest, synYpred))

# %%
cm = confusion_matrix(synYtest, synYpred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap=customCmap, xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix', fontsize = 16, fontweight = 'bold')
plt.xlabel('Predicted Label', fontsize = 12)
plt.ylabel('True Label', fontsize = 12)
plt.tight_layout()
